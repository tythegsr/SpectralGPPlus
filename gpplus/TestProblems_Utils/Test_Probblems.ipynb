# %%
from base import *

# %%
from GearTrain import *

# %%
D = 4
Function = GearTrain(is_mixed=False, to_print_Xscaled=True)

# %%
GX, FX = Function.evaluate(torch.rand(5,D))
# Out:
# X: tensor([[0.5794, 0.9899, 0.9960, 0.1084],
#         [0.7597, 0.9532, 0.3119, 0.8083],
#         [0.8087, 0.9644, 0.3373, 0.5771],
#         [0.1420, 0.2883, 0.9609, 0.3719],
#         [0.7084, 0.9174, 0.4602, 0.6135]])

# %%
Function = GearTrain(is_mixed=True, to_print_Xscaled=True)
GX, FX = Function.evaluate(torch.rand(5,D))
# Out:
# X: tensor([[50, 46, 39, 52],
#         [53, 34, 53, 56],
#         [34, 51, 41, 32],
#         [41, 35, 58, 33],
#         [39, 28, 38, 59]])

# %%
# tags[2]
